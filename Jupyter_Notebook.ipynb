# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0105EN-SkillsNetwork/labs/Module2/images/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo">
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# # My Jupyter Notebook on IBM Whatson Studio

# %% [markdown]
# **Farooq Niaz**
#
# **I am Currently a Student**

# %% [markdown]
# *I am interested in data science because I am doing Bs in Data Science and Want to Improve My Skills*

# %% [markdown]
# ### Below code Append Two lists

# %%
list1 = [1,2,3,4,5]
list2 = ['a','b','c','d','e']

list1.append(list2)
list1
# Out:
# [1, 2, 3, 4, 5, ['a', 'b', 'c', 'd', 'e']]

# %% [markdown]
# |List1|List2|
# |-----|-----|
# |  1  |  a  |
# |  2  |  b  |
# |  3  |  c  |
#
#
# - This is Two Lists Table
#
# ***![download.jpg](attachment:download.jpg)
